# %%
import polars as pl
from plotnine import *

# %% [markdown]
# ## Merge max into the big annotations file

# %%
anno = pl.scan_parquet("/s/project/deeprvat/wgs_preprocessing_rap/annotation/genebass1e6_genes_10kb_allvars_annotated.parquet")
anno.head().collect()

# %%
absp = pl.scan_parquet("/s/project/deeprvat/wgs_preprocessing_rap/annotation/absplice2/absplice2_all_ukb_vars_genebass1e6.parquet")
absp.head().collect()

# %%
absp.select(['id', 'region']).unique().collect()
