# %%
import os
import gc
import zarr
import yaml
import json
import numba
import numpy as np
import polars as pl
import pandas as pd
from tqdm import tqdm
import statsmodels.api as sm
from scipy import stats

from plotnine import *
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

from anngeno import AnnGeno
# Out:
# /home/dnanexus/anngeno/anngeno/anngeno.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %% [markdown]
# ## Read genebass associations

# %%
# Read the full Genebass results
pval_cutoffs = {'burden': 6.7e-7, 'skato': 2.5e-7}

# Convert the pandas operations into a single Polars expression
gb_pl = (
    pl.read_parquet('/home/dnanexus/data_dir/association_files/genebass_all_associations_p_e-5.parquet')
    .with_columns(
        significant = (pl.col('Pvalue') < pval_cutoffs['skato']) | (pl.col('Pvalue_Burden') < pval_cutoffs['burden']),
        phenotype = pl.col('description').str.replace_all(r"\(", "").str.replace_all(r"\)", "").str.replace_all(' ', '_').str.replace_all('-', '').str.replace_all("'", '').str.replace_all(',', '').str.to_lowercase() + '_int',
        region = pl.col('gene_id'),
        gene_name = pl.col('gene_symbol'),
    )
    .filter(
        (pl.col('significant') == True) &
        (pl.col('trait_type') == 'continuous') &
        # (pl.col('annotation').str.contains('pLoF'))
        (pl.col('annotation') == 'pLoF')
    )
    .select(['region', 'gene_name', 'phenotype', 'trait_type'])
    .unique()
)

gene_trait_df = gb_pl[['region', 'gene_name', 'phenotype', 'trait_type']].unique()

plof = pl.read_parquet('/home/dnanexus/data_dir/association_files/rvat_EUR_500k_regenie.parquet').with_columns(
    phenotype = (pl.col('trait') + '_int'),
    region = pl.col('gene_id'),
    rvat_pval = (10** -pl.col("neg_log10p")),
).filter(
    (pl.col('trait_type') == 'quantitative')
)
gene_trait_df = gb_pl.join(plof[['region', 'phenotype', 'beta', 'rvat_pval']], on=['region', 'phenotype'], how='inner')

lofcorr_df = pl.read_parquet("/home/dnanexus/data_dir/association_files/loftee_correlation_quantitative_EUR_genebass1e6coding_maf1e3.parquet")

gene_trait_df = gene_trait_df.join(lofcorr_df, on=['region', 'gene_name', 'phenotype'], how='left').with_columns(
    sign_agreement = (pl.col('loftee_corr')*pl.col('beta') > 0) & (pl.col('loftee_corr').is_not_nan()),
    corr_dir = (pl.col('loftee_corr')/pl.col('loftee_corr').abs())
)

# TODO: We don't cover all genebass significant genes, so we need to filter out nans (LOFTEE correlations missing)
# gene_trait_df = gene_trait_df.filter(pl.col('sign_agreement')==1)
gene_trait_df
# Out:
# shape: (1_322, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ region    ┆ gene_name ┆ phenotype ┆ trait_typ ┆ … ┆ t_stat    ┆ corr_pval ┆ sign_agre ┆ corr_dir │
# │ ---       ┆ ---       ┆ ---       ┆ e         ┆   ┆ ---       ┆ ---       ┆ ement     ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f32      │
# │           ┆           ┆           ┆ str       ┆   ┆           ┆           ┆ bool      ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ PAPPA2    ┆ arm_fatfr ┆ continuou ┆ … ┆ -4.681031 ┆ 0.000003  ┆ true      ┆ -1.0     │
# │ 116183    ┆           ┆ ee_mass_r ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ COPB1     ┆ arm_fatfr ┆ continuou ┆ … ┆ -5.174315 ┆ 3.2549e-7 ┆ true      ┆ -1.0     │
# │ 129083    ┆           ┆ ee_mass_r ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ KIAA0586  ┆ arm_fatfr ┆ continuou ┆ … ┆ -1.217545 ┆ 0.223659  ┆ true      ┆ -1.0     │
# │ 100578    ┆           ┆ ee_mass_r ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ACAN      ┆ arm_fatfr ┆ continuou ┆ … ┆ -9.169199 ┆ 1.1354e-1 ┆ true      ┆ -1.0     │
# │ 157766    ┆           ┆ ee_mass_r ┆ s         ┆   ┆           ┆ 9         ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ IGF1R     ┆ arm_fatfr ┆ continuou ┆ … ┆ -5.157856 ┆ 2.9651e-7 ┆ true      ┆ -1.0     │
# │ 140443    ┆           ┆ ee_mass_r ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ RHAG      ┆ reticuloc ┆ continuou ┆ … ┆ 3.136737  ┆ 0.001871  ┆ true      ┆ 1.0      │
# │ 112077    ┆           ┆ yte_count ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _int      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ANK1      ┆ reticuloc ┆ continuou ┆ … ┆ 10.431616 ┆ 1.3985e-2 ┆ true      ┆ 1.0      │
# │ 029534    ┆           ┆ yte_count ┆ s         ┆   ┆           ┆ 4         ┆           ┆          │
# │           ┆           ┆ _int      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ VPS13A    ┆ reticuloc ┆ continuou ┆ … ┆ 1.627776  ┆ 0.103726  ┆ true      ┆ 1.0      │
# │ 197969    ┆           ┆ yte_count ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _int      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ LRP5      ┆ heel_bone ┆ continuou ┆ … ┆ -4.663647 ┆ 0.000004  ┆ true      ┆ -1.0     │
# │ 162337    ┆           ┆ _mineral_ ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ SMAD6     ┆ heel_bone ┆ continuou ┆ … ┆ -3.963041 ┆ 0.000084  ┆ true      ┆ -1.0     │
# │ 137834    ┆           ┆ _mineral_ ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
a = gene_trait_df[['phenotype', 'gene_name', 'region', 'top_plof_var', 'top_plof_var_count']].group_by('gene_name').agg(
    pl.col('top_plof_var').n_unique(),
    pl.col('top_plof_var_count').n_unique()
).sort('top_plof_var', descending=True)

a.filter(pl.col('top_plof_var') > 1)
# Out:
# shape: (12, 3)
# ┌───────────┬──────────────┬────────────────────┐
# │ gene_name ┆ top_plof_var ┆ top_plof_var_count │
# │ ---       ┆ ---          ┆ ---                │
# │ str       ┆ u64          ┆ u64                │
# ╞═══════════╪══════════════╪════════════════════╡
# │ RORC      ┆ 3            ┆ 1                  │
# │ RRM1      ┆ 3            ┆ 1                  │
# │ SUPT5H    ┆ 2            ┆ 1                  │
# │ SLC22A2   ┆ 2            ┆ 2                  │
# │ PDE3B     ┆ 2            ┆ 10                 │
# │ …         ┆ …            ┆ …                  │
# │ RIF1      ┆ 2            ┆ 2                  │
# │ PLIN1     ┆ 2            ┆ 4                  │
# │ NPR2      ┆ 2            ┆ 2                  │
# │ SLC4A1    ┆ 2            ┆ 2                  │
# │ TRIM40    ┆ 2            ┆ 3                  │
# └───────────┴──────────────┴────────────────────┘

# %% [markdown]
# ## Plot single gene-trait assoc

# %%
gene_name = 'E2F8'
phenotype = 'mean_corpuscular_volume_int'

gtdf = gene_trait_df.filter(
    (pl.col('phenotype') == phenotype) &
    (pl.col('gene_name') == gene_name)
)
gene_id = gtdf['region'].unique().item()

# gene_name = "MRPL18"
# phenotype = "lipoprotein_a_int"
# gene_id = "ENSG00000112110"

ag = AnnGeno('/home/dnanexus/data_dir/genebass_1e6_coding_variants.ag', low_mem=True)
var_list = set(pl.read_parquet('/home/dnanexus/data_dir/genebass_1e6_coding_variants.ag/annotations.parquet', columns=['id',  'af_ukb']).filter(pl.col('af_ukb') < 1e-3)['id'].to_list())# - set(["chr11:19224693:G:A"])
ag.subset_variants(var_list)
gdata = ag.get_many_regions([gene_id])[gene_id]

# --- Get top plof variant and compute burdens ---
tpv = gtdf['top_plof_var'].item()
indices = np.where(gdata['variant_ids'] == tpv)[0]

# --- Drop top plof variant and compute burdens ---
# gdata['genotypes'] = np.delete(gdata['genotypes'], indices, axis=0)
# gdata['annotations'] = gdata['annotations'].filter(pl.col('id')!=tpv)

var_scores = gdata['annotations']['loftee_hc'].to_numpy() + gdata['annotations']['am_pathogenicity'].to_numpy()

plof_burdens = pl.DataFrame({
    'individual': ag.samples,
    'loftee': gdata['genotypes'].T @ gdata['annotations']['loftee_hc'].to_numpy(),
    'am_loftee': gdata['genotypes'].T @ var_scores
})#.filter(pl.col('burden') < 2)


# --- 2. Read and merge data ---
config_path = f'/home/dnanexus/ukbgym/config.yaml'
with open(config_path) as f:
    config = yaml.safe_load(f)
cov_list = config.get("covariates", [])

pheno_path = '/home/dnanexus/data_dir/phenotypes/phenotypes190_missing20_unique2_int.parquet'
prs_path = '/home/dnanexus/data_dir/phenotypes/PRS190_EUR_missing20_unique2_int.parquet'
cov_path = '/home/dnanexus/data_dir/phenotypes/250709_quant_phenotypes_covariates_genetic_pcs_prs_corrected.parquet'

pheno_lazy = pl.scan_parquet(pheno_path).select("IID", phenotype).rename({"IID": "individual"}).with_columns(pl.col("individual").cast(pl.String)) # Cast to String
prs_lazy = pl.scan_parquet(prs_path).select("IID", f"{phenotype}_prs").rename({"IID": "individual"}).with_columns(pl.col("individual").cast(pl.String)) # Cast to String
cov_lazy = pl.scan_parquet(cov_path).select("sample", *cov_list).rename({"sample": "individual"})

# Join everything and collect into a pandas DataFrame for the regression
merged_pd = (
    pheno_lazy
    .join(prs_lazy, on="individual", how="inner")
    .join(cov_lazy, on="individual", how="inner")
    .drop_nulls()
    .drop_nans()
    .collect()
    .to_pandas()
)

# --- 3. Compute residuals for the single phenotype ---
# Define the dependent (y) and independent (X) variables
y = merged_pd[phenotype]
X = merged_pd[[f"{phenotype}_prs"] + cov_list]
X = sm.add_constant(X) # Add an intercept

# Fit the linear model and get the residuals
model = sm.OLS(y, X).fit()
residuals = model.resid

# --- 4. Create the final long-format DataFrame ---
p_df = pl.DataFrame({
    "individual": merged_pd["individual"].astype(str),
    "phenotype": phenotype,
    "pheno_value": residuals
})

# 4. Join with gene burdens
plot_gp_df = plof_burdens.join(p_df, on='individual', how='inner')
print('Number of plofs:', plot_gp_df['loftee'].sum())

plot_gp_df
# Out:
# /home/dnanexus/deeprvat2-env/lib/python3.11/site-packages/zarr/codecs/vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
# /home/dnanexus/deeprvat2-env/lib/python3.11/site-packages/zarr/codecs/vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
# Number of plofs: 241
# shape: (352_821, 5)
# ┌────────────┬────────┬───────────┬─────────────────────────────┬─────────────┐
# │ individual ┆ loftee ┆ am_loftee ┆ phenotype                   ┆ pheno_value │
# │ ---        ┆ ---    ┆ ---       ┆ ---                         ┆ ---         │
# │ str        ┆ i8     ┆ f64       ┆ str                         ┆ f64         │
# ╞════════════╪════════╪═══════════╪═════════════════════════════╪═════════════╡
# │ 3834985    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.153881    │
# │ 1649233    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.624524    │
# │ 5689749    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.250983    │
# │ 1160905    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.613218    │
# │ 5102203    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.907655    │
# │ …          ┆ …      ┆ …         ┆ …                           ┆ …           │
# │ 5733954    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.520647    │
# │ 3923515    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.864572    │
# │ 3548117    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ -0.581094   │
# │ 1732136    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.323834    │
# │ 5618419    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_int ┆ 0.334744    │
# └────────────┴────────┴───────────┴─────────────────────────────┴─────────────┘

# %%
# Cast 'loftee' to a boolean type
plot_gp_df = plot_gp_df.with_columns(
    # use the Unicode 'greater-than-or-equal-to' character (U+2265)
    loftee_label = pl.when(pl.col("loftee") == 0).then(pl.lit('0')).otherwise(pl.lit('\u2265 1')),
    # loftee_label = pl.when(pl.col("loftee") == 0).then(pl.lit('0')).otherwise(pl.lit('>=1')),
    # if you prefer pure ASCII, use '>=' instead of '\u2265'
    alpha = pl.when(pl.col("loftee") == 0).then(0).otherwise(0.5)
)

plot_gp_df
# Out:
# shape: (352_821, 7)
# ┌────────────┬────────┬───────────┬───────────────────────────┬─────────────┬──────────────┬───────┐
# │ individual ┆ loftee ┆ am_loftee ┆ phenotype                 ┆ pheno_value ┆ loftee_label ┆ alpha │
# │ ---        ┆ ---    ┆ ---       ┆ ---                       ┆ ---         ┆ ---          ┆ ---   │
# │ str        ┆ i8     ┆ f64       ┆ str                       ┆ f64         ┆ str          ┆ f64   │
# ╞════════════╪════════╪═══════════╪═══════════════════════════╪═════════════╪══════════════╪═══════╡
# │ 3834985    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.153881    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 1649233    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.624524    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 5689749    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.250983    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 1160905    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.613218    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 5102203    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.907655    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ …          ┆ …      ┆ …         ┆ …                         ┆ …           ┆ …            ┆ …     │
# │ 5733954    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.520647    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 3923515    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.864572    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 3548117    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ -0.581094   ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 1732136    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.323834    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# │ 5618419    ┆ 0      ┆ 0.0       ┆ mean_corpuscular_volume_i ┆ 0.334744    ┆ 0            ┆ 0.0   │
# │            ┆        ┆           ┆ nt                        ┆             ┆              ┆       │
# └────────────┴────────┴───────────┴───────────────────────────┴─────────────┴──────────────┴───────┘

# %%
(
    ggplot(plot_gp_df, aes(x='loftee_label', y='pheno_value')) +
    geom_boxplot(width=0.75) +
    geom_jitter(aes(alpha='alpha'), width=0.35, size=0.25, height=0) +
    scale_alpha_identity() +
    theme_minimal() +
    labs(
        x='LOFTEE variants',
        y=f"Mean corpuscular volume",
        title=f"{gene_name} - {plot_gp_df['loftee'].sum()} pLoF carriers"
    ) +
    theme(
        figure_size=(2.75, 3),
        legend_position='none',
        axis_text=element_text(size=13),
        axis_title=element_text(size=13),
    )
)

# %%
(
    ggplot(plot_gp_df, aes(x='loftee', y='pheno_value')) +
    geom_point(alpha=0.1) +
    geom_smooth(method='lm', se=True, color='darkred') +
    theme_minimal() +
    labs(
        x='gene burden',
        y=f"{phenotype} value",
        title=f"{gene_name}" # ({plot_gp_df['burden'].sum()}/{plot_gp_df.shape[0]} plof)"
    ) +
    theme(figure_size=(3, 3))
)

# %% [markdown]
# ## Get p-values across all associations

# %%
config_path = f'/home/dnanexus/ukbgym/config.yaml'
with open(config_path) as f:
    config = yaml.safe_load(f)
cov_list = config.get("covariates", [])

pheno_path = '/home/dnanexus/data_dir/phenotypes/phenotypes190_missing20_unique2_int.parquet'
prs_path = '/home/dnanexus/data_dir/phenotypes/PRS190_EUR_missing20_unique2_int.parquet'
cov_path = '/home/dnanexus/data_dir/phenotypes/250709_quant_phenotypes_covariates_genetic_pcs_prs_corrected.parquet'

pheno_lazy = pl.scan_parquet(pheno_path).rename({"IID": "individual"}).with_columns(pl.col("individual").cast(pl.String)) # Cast to String
prs_lazy = pl.scan_parquet(prs_path).rename({"IID": "individual"}).with_columns(pl.col("individual").cast(pl.String)) # Cast to String
cov_lazy = pl.scan_parquet(cov_path).select("sample", *cov_list).rename({"sample": "individual"})

ag = AnnGeno('/home/dnanexus/data_dir/genebass_1e6_coding_variants.ag', low_mem=True)
var_list = set(pl.read_parquet('/home/dnanexus/data_dir/genebass_1e6_coding_variants.ag/annotations.parquet', columns=['id', 'af_ukb']).filter(pl.col('af_ukb') < 1e-3)['id'].to_list())
ag.subset_variants(var_list)
# Out:
# /home/dnanexus/deeprvat2-env/lib/python3.11/site-packages/zarr/codecs/vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
# /home/dnanexus/deeprvat2-env/lib/python3.11/site-packages/zarr/codecs/vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.

# %%
plof = pl.read_parquet('/home/dnanexus/data_dir/association_files/rvat_EUR_500k_regenie.parquet').with_columns(
    phenotype = (pl.col('trait') + '_int'),
    region = pl.col('gene_id'),
    rvat_pval = (10** -pl.col("neg_log10p")),
).filter(
    (pl.col('trait_type') == 'quantitative')
).select(['region', 'gene_id', 'gene_name', 'phenotype', 'beta', 'rvat_pval'])

lofcorr_df = pl.read_parquet("/home/dnanexus/data_dir/association_files/loftee_correlation_quantitative_EUR_genebass1e6coding_maf1e3.parquet")

plof = plof.join(lofcorr_df, on=['region', 'gene_name', 'phenotype'], how='inner')

# Apply bonferroni correction
rvat_df = plof.filter(pl.col('gene_id').is_in(ag.region_ids)).with_columns(
    p_adj_bonf = pl.min_horizontal(pl.col('rvat_pval')*17_500, 1)
).filter(pl.col('p_adj_bonf') < 0.05)

# rvat_df = gene_trait_df.head()
rvat_df
# Out:
# shape: (1_047, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ region    ┆ gene_id   ┆ gene_name ┆ phenotype ┆ … ┆ plof_prop ┆ t_stat    ┆ corr_pval ┆ p_adj_bo │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ nf       │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ ENSG00000 ┆ PAPPA2    ┆ arm_fatfr ┆ … ┆ 0.0546875 ┆ -4.681031 ┆ 0.000003  ┆ 0.001604 │
# │ 116183    ┆ 116183    ┆           ┆ ee_mass_r ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ight_int  ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ CNPY2     ┆ arm_fatfr ┆ … ┆ 0.134752  ┆ -1.612251 ┆ 0.109176  ┆ 0.01353  │
# │ 257727    ┆ 257727    ┆           ┆ ee_mass_r ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ight_int  ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ ACAN      ┆ arm_fatfr ┆ … ┆ 0.027094  ┆ -9.169199 ┆ 1.1354e-1 ┆ 0.000001 │
# │ 157766    ┆ 157766    ┆           ┆ ee_mass_r ┆   ┆           ┆           ┆ 9         ┆          │
# │           ┆           ┆           ┆ ight_int  ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ IGF1R     ┆ arm_fatfr ┆ … ┆ 0.042086  ┆ -5.157856 ┆ 2.9651e-7 ┆ 0.000501 │
# │ 140443    ┆ 140443    ┆           ┆ ee_mass_r ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ight_int  ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ G6PC1     ┆ arm_fatfr ┆ … ┆ 0.089552  ┆ 0.500214  ┆ 0.617338  ┆ 0.014008 │
# │ 131482    ┆ 131482    ┆           ┆ ee_mass_r ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ight_int  ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ ENSG00000 ┆ RHAG      ┆ reticuloc ┆ … ┆ 0.050794  ┆ 3.136737  ┆ 0.001871  ┆ 3.1567e- │
# │ 112077    ┆ 112077    ┆           ┆ yte_count ┆   ┆           ┆           ┆           ┆ 37       │
# │           ┆           ┆           ┆ _int      ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ ANK1      ┆ reticuloc ┆ … ┆ 0.024425  ┆ 10.431616 ┆ 1.3985e-2 ┆ 0.000004 │
# │ 029534    ┆ 029534    ┆           ┆ yte_count ┆   ┆           ┆           ┆ 4         ┆          │
# │           ┆           ┆           ┆ _int      ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ VPS13A    ┆ reticuloc ┆ … ┆ 0.109917  ┆ 1.627776  ┆ 0.103726  ┆ 0.003708 │
# │ 197969    ┆ 197969    ┆           ┆ yte_count ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ _int      ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ LRP5      ┆ heel_bone ┆ … ┆ 0.032979  ┆ -4.663647 ┆ 0.000004  ┆ 0.00001  │
# │ 162337    ┆ 162337    ┆           ┆ _mineral_ ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ density_b ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ md_…      ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ENSG00000 ┆ MEPE      ┆ heel_bone ┆ … ┆ 0.013514  ┆ -0.141097 ┆ 0.887922  ┆ 6.0595e- │
# │ 152595    ┆ 152595    ┆           ┆ _mineral_ ┆   ┆           ┆           ┆           ┆ 7        │
# │           ┆           ┆           ┆ density_b ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ md_…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Read the full Genebass results
pval_cutoffs = {'burden': 6.7e-7, 'skato': 2.5e-7}

# Convert the pandas operations into a single Polars expression
gb_pl = (
    pl.read_parquet('/home/dnanexus/data_dir/association_files/genebass_all_associations_p_e-5.parquet')
    .with_columns(
        significant = (pl.col('Pvalue') < pval_cutoffs['skato']) | (pl.col('Pvalue_Burden') < pval_cutoffs['burden']),
        phenotype = pl.col('description').str.replace_all(r"\(", "").str.replace_all(r"\)", "").str.replace_all(' ', '_').str.replace_all('-', '').str.replace_all("'", '').str.replace_all(',', '').str.to_lowercase() + '_int',
        region = pl.col('gene_id'),
        gene_name = pl.col('gene_symbol'),
    )
    .filter(
        (pl.col('significant') == True) &
        (pl.col('trait_type') == 'continuous') &
        (pl.col('phenotype').is_in(plof['phenotype'].unique())) &
        (pl.col('annotation') == 'pLoF')
    )
    .select(['region', 'gene_name', 'phenotype'])
    .unique()
)

gb_pl
# Out:
# /tmp/ipykernel_538689/1932594681.py:13: DeprecationWarning: `is_in` with a collection of the same datatype is ambiguous and deprecated.
# Please use `implode` to return to previous behavior.
#
# See https://github.com/pola-rs/polars/issues/22149 for more information.
# shape: (1_378, 3)
# ┌─────────────────┬───────────┬─────────────────────────────────┐
# │ region          ┆ gene_name ┆ phenotype                       │
# │ ---             ┆ ---       ┆ ---                             │
# │ str             ┆ str       ┆ str                             │
# ╞═════════════════╪═══════════╪═════════════════════════════════╡
# │ ENSG00000106819 ┆ ASPN      ┆ standing_height_int             │
# │ ENSG00000127585 ┆ FBXL16    ┆ arm_fat_percentage_left_int     │
# │ ENSG00000066827 ┆ ZFAT      ┆ sitting_height_int              │
# │ ENSG00000196712 ┆ NF1       ┆ white_blood_cell_leukocyte_cou… │
# │ ENSG00000113013 ┆ HSPA9     ┆ mean_corpuscular_haemoglobin_i… │
# │ …               ┆ …         ┆ …                               │
# │ ENSG00000169047 ┆ IRS1      ┆ weight_int                      │
# │ ENSG00000110243 ┆ APOA5     ┆ platelet_distribution_width_in… │
# │ ENSG00000165029 ┆ ABCA1     ┆ cholesterol_int                 │
# │ ENSG00000166819 ┆ PLIN1     ┆ triglycerides_int               │
# │ ENSG00000168769 ┆ TET2      ┆ white_blood_cell_leukocyte_cou… │
# └─────────────────┴───────────┴─────────────────────────────────┘

# %%
assoc_union = pl.concat([rvat_df[['region', 'gene_name', 'phenotype']], gb_pl]).unique().filter(pl.col('region').is_in(ag.region_ids)).filter(pl.col('gene_name')!='G6PC')
gene_trait_df = assoc_union.join(plof, on=['region', 'gene_name', 'phenotype'], how='left')
gene_trait_df
# Out:
# shape: (1_590, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ region    ┆ gene_name ┆ phenotype ┆ gene_id   ┆ … ┆ top_plof_ ┆ plof_prop ┆ t_stat    ┆ corr_pva │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ var_count ┆ ---       ┆ ---       ┆ l        │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ u32       ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ PLIN4     ┆ trunk_fat ┆ ENSG00000 ┆ … ┆ 152       ┆ 0.068716  ┆ -2.674126 ┆ 0.007566 │
# │ 167676    ┆           ┆ _percenta ┆ 167676    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ge_int    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ LOXL2     ┆ standing_ ┆ ENSG00000 ┆ … ┆ 279       ┆ 0.071331  ┆ 0.047216  ┆ 0.962354 │
# │ 134013    ┆           ┆ height_in ┆ 134013    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ t         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ZFAT      ┆ arm_predi ┆ ENSG00000 ┆ … ┆ 81        ┆ 0.04913   ┆ 4.804199  ┆ 0.000002 │
# │ 066827    ┆           ┆ cted_mass ┆ 066827    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _left_int ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ GHRH      ┆ igf1_int  ┆ ENSG00000 ┆ … ┆ 67        ┆ 0.111111  ┆ -1.410628 ┆ 0.162783 │
# │ 118702    ┆           ┆           ┆ 118702    ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ DIDO1     ┆ arm_fat_p ┆ ENSG00000 ┆ … ┆ 2         ┆ 0.0115    ┆ 4.590144  ┆ 0.000005 │
# │ 101191    ┆           ┆ ercentage ┆ 101191    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _left_int ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ CD36      ┆ alkaline_ ┆ ENSG00000 ┆ … ┆ 244       ┆ 0.177645  ┆ 0.692615  ┆ 0.488874 │
# │ 135218    ┆           ┆ phosphata ┆ 135218    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ se_int    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ TRPM7     ┆ sitting_h ┆ ENSG00000 ┆ … ┆ 197       ┆ 0.100587  ┆ -3.684525 ┆ 0.000239 │
# │ 092439    ┆           ┆ eight_int ┆ 092439    ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ NCOR1     ┆ forced_ex ┆ ENSG00000 ┆ … ┆ 192       ┆ 0.031593  ┆ -5.898029 ┆ 4.5679e- │
# │ 141027    ┆           ┆ piratory_ ┆ 141027    ┆   ┆           ┆           ┆           ┆ 9        │
# │           ┆           ┆ volume_in ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _1s…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ SUPT5H    ┆ red_blood ┆ ENSG00000 ┆ … ┆ 2         ┆ 0.027027  ┆ 9.661003  ┆ 8.1706e- │
# │ 196235    ┆           ┆ _cell_ery ┆ 196235    ┆   ┆           ┆           ┆           ┆ 21       │
# │           ┆           ┆ throcyte_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ dis…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ ATP13A1   ┆ arm_fat_m ┆ ENSG00000 ┆ … ┆ 37        ┆ 0.033914  ┆ 4.219009  ┆ 0.000027 │
# │ 105726    ┆           ┆ ass_right ┆ 105726    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _int      ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# gene_id = 'ENSG00000130164'
rvat_df_list = []
for gene_id in tqdm(gene_trait_df['region'].unique().to_list()):
    gdata = ag.get_many_regions([gene_id])[gene_id]
    gene_name = gene_trait_df.filter(pl.col('region') == gene_id)['gene_name'].unique().item()

    pheno_list = gene_trait_df.filter(pl.col('region') == gene_id)['phenotype'].to_list()
    for phenotype in tqdm(pheno_list):
        gtdf = gene_trait_df.filter(
            (pl.col('phenotype') == phenotype) &
            (pl.col('region') == gene_id)
        ).with_columns(
            n_plof_variants = pl.when(pl.col('n_plof_variants').is_null()).then(0).otherwise(pl.col('n_plof_variants')),
        )
        
        if gtdf['n_plof_variants'].item() > 1:
            tpv = gtdf['top_plof_var'].item()
            indices = np.where(gdata['variant_ids'] == tpv)[0]
            plof_burdens = pl.DataFrame({
                'individual': ag.samples,
                'burden': np.delete(gdata['genotypes'], indices, axis=0).T @ gdata['annotations'].filter(pl.col('id')!=tpv)['loftee_hc'].to_numpy()
            })#.filter(pl.col('burden') < 2)

            # Join everything and collect into a pandas DataFrame for the regression
            merged_pd = (
                pheno_lazy.select("individual", phenotype)
                .join(plof_burdens.lazy(), on="individual", how="inner")
                .join(prs_lazy.select("individual", f"{phenotype}_prs"), on="individual", how="inner")
                .join(cov_lazy, on="individual", how="inner")
                .drop_nulls()
                .drop_nans()
                .collect(engine='streaming')
            )

            # --- 3. Compute residuals for the single phenotype ---
            y = merged_pd[phenotype].to_numpy()
            X = merged_pd[["burden", f"{phenotype}_prs"] + cov_list].to_numpy()
            X = sm.add_constant(X) # Add an intercept

            # Fit the linear model and get the residuals
            model = sm.OLS(y, X).fit()
            pval = model.pvalues[1]
            beta = model.params[1]
            n_plofs = int(plof_burdens['burden'].sum())

        else:
            pval = np.nan
            beta = np.nan
            n_plofs = 0

        rvat_df_list.append(pl.DataFrame({
            "phenotype": phenotype,
            "gene_name": gene_name,
            "region": gene_id,
            "p_value": pval,
            "beta": beta,
            "n_variants": gtdf['n_variants'].item(),
            "n_plofs": n_plofs,
            "dropped_plof_count": gtdf['top_plof_var_count'].item(),
            "dropped_plof": gtdf['top_plof_var'].item(),
        }))

rvat_wo_top_plof = pl.concat(rvat_df_list)
rvat_wo_top_plof.write_parquet("/home/dnanexus/data_dir/association_files/rvat_loftee_union_genebass_assocs_wo_top_plof_EUR_500k.parquet")
rvat_wo_top_plof
# Out:
# 100%|██████████| 3/3 [00:07<00:00,  2.39s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.20s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.73s/it]t]
# 100%|██████████| 14/14 [00:34<00:00,  2.47s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]/it]
# 100%|██████████| 20/20 [01:07<00:00,  3.37s/it]t]
# 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]s/it]
# 100%|██████████| 3/3 [00:08<00:00,  2.99s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]it]
# 100%|██████████| 6/6 [00:13<00:00,  2.22s/it]it]
# 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]it]
# 100%|██████████| 1/1 [00:00<00:00, 724.03it/s]t]
# 100%|██████████| 2/2 [00:05<00:00,  2.58s/it]it]
# 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]it]
# 100%|██████████| 6/6 [00:05<00:00,  1.03it/s]it]
# 100%|██████████| 2/2 [00:03<00:00,  1.67s/it]it]
# 100%|██████████| 1/1 [00:02<00:00,  2.39s/it]it]
# 100%|██████████| 1/1 [00:03<00:00,  3.77s/it]it]
# 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]it]
# 100%|██████████| 3/3 [00:02<00:00,  1.16it/s]it]
# 100%|██████████| 10/10 [00:09<00:00,  1.06it/s]]
# 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]it]
# 100%|██████████| 1/1 [00:05<00:00,  5.52s/it]it]
# 100%|██████████| 17/17 [00:09<00:00,  1.75it/s]]
# 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]it]
# 100%|██████████| 1/1 [00:00<00:00, 1001.51it/s]]
# 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]it]
# 100%|██████████| 19/19 [01:18<00:00,  4.13s/it]]
# 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]s/it]
# 100%|██████████| 14/14 [01:39<00:00,  7.11s/it]it]
# 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]s/it]
# 100%|██████████| 4/4 [00:00<00:00, 1202.41it/s]it]
# 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]s/it]
# 100%|██████████| 13/13 [00:31<00:00,  2.45s/it]it]
# 100%|██████████| 3/3 [00:03<00:00,  1.07s/it]s/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.57s/it]s/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]it]
# 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]it]
# 100%|██████████| 2/2 [00:06<00:00,  3.27s/it]it]
# 100%|██████████| 6/6 [00:07<00:00,  1.20s/it]it]
# 100%|██████████| 3/3 [00:03<00:00,  1.21s/it]it]
# 100%|██████████| 11/11 [00:10<00:00,  1.08it/s]]
# 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]it]
# 100%|██████████| 9/9 [00:23<00:00,  2.59s/it]it]
# 100%|██████████| 7/7 [00:00<00:00, 1144.60it/s]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]it]
# 100%|██████████| 10/10 [00:16<00:00,  1.64s/it]]
# 100%|██████████| 3/3 [00:04<00:00,  1.57s/it]it]
# 100%|██████████| 3/3 [00:05<00:00,  1.73s/it]it]
# 100%|██████████| 9/9 [01:02<00:00,  6.94s/it]it]
# 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]s/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.48s/it]s/it]
# 100%|██████████| 4/4 [00:09<00:00,  2.38s/it]s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.58s/it]s/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]it]
# 100%|██████████| 3/3 [00:03<00:00,  1.16s/it]it]
# 100%|██████████| 4/4 [00:11<00:00,  2.94s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.54s/it]it]
# 100%|██████████| 3/3 [00:15<00:00,  5.31s/it]it]
# 100%|██████████| 2/2 [00:03<00:00,  1.74s/it]s/it]
# 100%|██████████| 7/7 [00:07<00:00,  1.05s/it]it]
# 100%|██████████| 3/3 [00:04<00:00,  1.57s/it]it]
# 100%|██████████| 4/4 [00:04<00:00,  1.14s/it]it]
# 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]it]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]it]
# 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]it]
# 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]it]
# 100%|██████████| 11/11 [00:23<00:00,  2.18s/it]]
# 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]it]
# 100%|██████████| 7/7 [00:12<00:00,  1.72s/it]it]
# 100%|██████████| 4/4 [00:06<00:00,  1.72s/it]it]
# 100%|██████████| 12/12 [00:10<00:00,  1.16it/s]]
# 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]it]
# 100%|██████████| 2/2 [00:03<00:00,  1.77s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]it]
# 100%|██████████| 11/11 [00:14<00:00,  1.28s/it]]
# 100%|██████████| 1/1 [00:04<00:00,  4.02s/it]it]
# 100%|██████████| 2/2 [00:03<00:00,  1.57s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]it]
# 100%|██████████| 2/2 [00:04<00:00,  2.33s/it]it]
# 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]it]
# 100%|██████████| 15/15 [00:10<00:00,  1.48it/s]t]
# 100%|██████████| 2/2 [00:03<00:00,  1.55s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.85s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]/it]
# 100%|██████████| 12/12 [00:30<00:00,  2.56s/it]t]
# 100%|██████████| 3/3 [00:03<00:00,  1.31s/it]9s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]/it]
# 100%|██████████| 9/9 [00:13<00:00,  1.52s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]/it]
# 100%|██████████| 4/4 [00:04<00:00,  1.15s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]/it]
# 100%|██████████| 28/28 [00:00<00:00, 1287.06it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.81s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.62s/it]/it]
# 100%|██████████| 1/1 [00:05<00:00,  5.75s/it]/it]
# 100%|██████████| 9/9 [00:09<00:00,  1.05s/it]/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.36s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.19s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.46s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]/it]
# 100%|██████████| 4/4 [00:04<00:00,  1.00s/it]/it]
# 100%|██████████| 6/6 [00:08<00:00,  1.35s/it]/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.32s/it]/it]
# 100%|██████████| 2/2 [00:07<00:00,  3.58s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]/it]
# 100%|██████████| 1/1 [00:04<00:00,  4.82s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.59s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]/it]
# 100%|██████████| 30/30 [00:26<00:00,  1.14it/s]t]
# 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.91s/it]/it]
# 100%|██████████| 19/19 [01:10<00:00,  3.71s/it]t]
# 100%|██████████| 5/5 [00:00<00:00, 1230.07it/s]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]7s/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.77s/it]0s/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.97s/it]/it]
# 100%|██████████| 4/4 [00:03<00:00,  1.10it/s]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.23s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]/it]
# 100%|██████████| 3/3 [00:04<00:00,  1.37s/it]/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.40it/s]/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.81s/it]/it]
# 100%|██████████| 5/5 [00:18<00:00,  3.75s/it]/it]
# 100%|██████████| 14/14 [00:14<00:00,  1.01s/it]t]
# 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.61s/it]/it]
# 100%|██████████| 3/3 [00:06<00:00,  2.23s/it]/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.35s/it]/it]
# 100%|██████████| 17/17 [00:38<00:00,  2.29s/it]t]
# 100%|██████████| 3/3 [00:07<00:00,  2.58s/it]0s/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.17s/it]3s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.88s/it]/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.32s/it]/it]
# 100%|██████████| 2/2 [00:08<00:00,  4.09s/it]/it]
# 100%|██████████| 3/3 [00:20<00:00,  6.71s/it]/it]
# 100%|██████████| 17/17 [00:16<00:00,  1.02it/s]/it]
# 100%|██████████| 3/3 [00:10<00:00,  3.54s/it]6s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.84s/it]2s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]/it]
# 100%|██████████| 10/10 [00:23<00:00,  2.30s/it]t]
# 100%|██████████| 1/1 [00:02<00:00,  2.74s/it]/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.55s/it]/it]
# 100%|██████████| 4/4 [00:06<00:00,  1.74s/it]/it]
# 100%|██████████| 3/3 [00:04<00:00,  1.48s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.32s/it]/it]
# 100%|██████████| 8/8 [00:30<00:00,  3.82s/it]/it]
# 100%|██████████| 5/5 [00:03<00:00,  1.45it/s]8s/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.63s/it]/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.54s/it]/it]
# 100%|██████████| 4/4 [00:11<00:00,  2.79s/it]/it]
# 100%|██████████| 13/13 [00:13<00:00,  1.04s/it]t]
# 100%|██████████| 1/1 [00:02<00:00,  2.97s/it]/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.53s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]/it]
# 100%|██████████| 10/10 [00:46<00:00,  4.65s/it]t]
# 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]9s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]/it]
# 100%|██████████| 6/6 [00:17<00:00,  2.85s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00, 927.53it/s]it]
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]/it]
# 100%|██████████| 18/18 [01:12<00:00,  4.01s/it]t]
# 100%|██████████| 1/1 [00:02<00:00,  2.35s/it]5s/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.12s/it]3s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]6s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.78s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]/it]
# 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.56s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.59s/it]/it]
# 100%|██████████| 1/1 [00:05<00:00,  5.77s/it]/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]/it]
# 100%|██████████| 3/3 [00:05<00:00,  1.76s/it]/it]
# 100%|██████████| 4/4 [00:17<00:00,  4.34s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]/it]
# 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]/it]
# 100%|██████████| 6/6 [00:20<00:00,  3.34s/it]/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]/it]
# 100%|██████████| 20/20 [00:32<00:00,  1.63s/it]t]
# 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]3s/it]
# 100%|██████████| 4/4 [00:04<00:00,  1.04s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]/it]
# 100%|██████████| 4/4 [00:11<00:00,  2.78s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.23s/it]/it]
# 100%|██████████| 2/2 [00:06<00:00,  3.25s/it]/it]
# 100%|██████████| 5/5 [01:03<00:00, 12.80s/it]/it]
# 100%|██████████| 10/10 [00:28<00:00,  2.87s/it]/it]
# 100%|██████████| 4/4 [00:16<00:00,  4.02s/it]8s/it]
# 100%|██████████| 9/9 [00:20<00:00,  2.30s/it]6s/it]
# 100%|██████████| 4/4 [00:07<00:00,  1.90s/it]2s/it]
# 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]9s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.02s/it]/it]
# 100%|██████████| 3/3 [00:09<00:00,  3.25s/it]/it]
# 100%|██████████| 4/4 [00:03<00:00,  1.10it/s]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.70s/it]/it]
# 100%|██████████| 13/13 [00:53<00:00,  4.09s/it]t]
# 100%|██████████| 11/11 [00:13<00:00,  1.20s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]4s/it]
# 100%|██████████| 14/14 [00:38<00:00,  2.75s/it]t]
# 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]6s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]/it]
# 100%|██████████| 18/18 [00:55<00:00,  3.07s/it]t]
# 100%|██████████| 4/4 [00:40<00:00, 10.02s/it]5s/it]
# 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]2s/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.85s/it]5s/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.20s/it]/it]
# 100%|██████████| 3/3 [00:04<00:00,  1.61s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]/it]
# 100%|██████████| 23/23 [01:46<00:00,  4.64s/it]t]
# 100%|██████████| 1/1 [00:02<00:00,  2.69s/it]6s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]4s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]/it]
# 100%|██████████| 25/25 [01:00<00:00,  2.40s/it]t]
# 100%|██████████| 3/3 [00:05<00:00,  1.70s/it]9s/it]
# 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]3s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]/it]
# 100%|██████████| 11/11 [00:17<00:00,  1.59s/it]t]
# 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]/it]
# 100%|██████████| 4/4 [00:17<00:00,  4.38s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.08s/it]/it]
# 100%|██████████| 3/3 [00:05<00:00,  1.78s/it]/it]
# 100%|██████████| 2/2 [00:11<00:00,  5.51s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]/it]
# 100%|██████████| 4/4 [00:05<00:00,  1.40s/it]/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.99s/it]/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.03s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]/it]
# 100%|██████████| 3/3 [00:05<00:00,  1.92s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]/it]
# 100%|██████████| 7/7 [00:09<00:00,  1.38s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.65s/it]/it]
# 100%|██████████| 6/6 [00:07<00:00,  1.32s/it]/it]
# 100%|██████████| 6/6 [00:15<00:00,  2.61s/it]/it]
# 100%|██████████| 7/7 [00:18<00:00,  2.66s/it]/it]
# 100%|██████████| 3/3 [00:10<00:00,  3.41s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.64s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]/it]
# 100%|██████████| 1/1 [00:04<00:00,  4.23s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]/it]
# 100%|██████████| 8/8 [00:21<00:00,  2.69s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.15s/it]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.50s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]/it]
# 100%|██████████| 18/18 [00:50<00:00,  2.78s/it]t]
# 100%|██████████| 3/3 [00:05<00:00,  1.75s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.58s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]/it]
# 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]/it]
# 100%|██████████| 4/4 [00:06<00:00,  1.58s/it]/it]
# 100%|██████████| 3/3 [00:02<00:00,  1.19it/s]/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.78s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]/it]
# 100%|██████████| 5/5 [00:04<00:00,  1.11it/s]/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.01s/it]/it]
# 100%|██████████| 7/7 [00:25<00:00,  3.64s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.18s/it]/it]
# 100%|██████████| 5/5 [00:07<00:00,  1.47s/it]/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.20s/it]/it]
# 100%|██████████| 18/18 [00:39<00:00,  2.17s/it]t]
# 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.81s/it]/it]
# 100%|██████████| 9/9 [00:00<00:00, 1201.58it/s]t]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.26s/it]/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.28s/it]/it]
# 100%|██████████| 4/4 [00:02<00:00,  1.53it/s]/it]
# 100%|██████████| 1/1 [00:00<00:00, 898.72it/s]it]
# 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.72s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]/it]
# 100%|██████████| 4/4 [00:13<00:00,  3.27s/it]/it]
# 100%|██████████| 3/3 [00:04<00:00,  1.64s/it]/it]
# 100%|██████████| 3/3 [00:07<00:00,  2.48s/it]/it]
# 100%|██████████| 14/14 [00:12<00:00,  1.14it/s]t]
# 100%|██████████| 5/5 [00:19<00:00,  3.93s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.31s/it]/it]
# 100%|██████████| 6/6 [00:18<00:00,  3.04s/it]/it]
# 100%|██████████| 6/6 [00:09<00:00,  1.58s/it]/it]
# 100%|██████████| 2/2 [00:12<00:00,  6.49s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.86s/it]/it]
# 100%|██████████| 16/16 [00:54<00:00,  3.38s/it]t]
# 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]/it]
# 100%|██████████| 2/2 [00:12<00:00,  6.25s/it]/it]
# 100%|██████████| 3/3 [00:04<00:00,  1.59s/it]/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.59s/it]/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.74s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.86s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.81s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.40s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]/it]
# 100%|██████████| 5/5 [00:55<00:00, 11.07s/it]/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.67s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]/it]
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]t]
# 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]/it]
# 100%|██████████| 2/2 [00:06<00:00,  3.21s/it]/it]
# 100%|██████████| 1/1 [00:13<00:00, 13.80s/it]/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.28s/it]/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]/it]
# 100%|██████████| 4/4 [00:08<00:00,  2.01s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.58s/it]/it]
# 100%|██████████| 4/4 [00:06<00:00,  1.57s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]/it]
# 100%|██████████| 3/3 [00:05<00:00,  1.78s/it]/it]
# 100%|██████████| 5/5 [00:17<00:00,  3.52s/it]/it]
# 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]/it]
# 100%|██████████| 4/4 [00:08<00:00,  2.19s/it]/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.79s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.59s/it]/it]
#  89%|████████▊ | 399/450 [59:32<07:36,  8.95s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 for gene_id in tqdm(gene_trait_df['region'].unique().to_list()):
#       4     gdata = ag.get_many_regions([gene_id])[gene_id]
# ----> 5     gene_name = gene_trait_df.filter(pl.col('region') == gene_id)['gene_name'].unique().item()
#       7     pheno_list = gene_trait_df.filter(pl.col('region') == gene_id)['phenotype'].to_list()
#       8     for phenotype in tqdm(pheno_list):
#
# File ~/deeprvat2-env/lib/python3.11/site-packages/polars/series/series.py:1633, in Series.item(self, index)
#    1628     if len(self) != 1:
#    1629         msg = (
#    1630             "can only call '.item()' if the Series is of length 1,"
#    1631             f" or an explicit index is provided (Series is of length {len(self)})"
#    1632         )
# -> 1633         raise ValueError(msg)
#    1634     return self._s.get_index(0)
#    1636 return self._s.get_index_signed(index)
#
# ValueError: can only call '.item()' if the Series is of length 1, or an explicit index is provided (Series is of length 2)

# %%
gene_trait_df.filter(pl.col('region') == gene_id)
# Out:
# shape: (27, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ region    ┆ gene_name ┆ phenotype ┆ gene_id   ┆ … ┆ top_plof_ ┆ plof_prop ┆ t_stat    ┆ corr_pva │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ var_count ┆ ---       ┆ ---       ┆ l        │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ u32       ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ G6PC1     ┆ whole_bod ┆ ENSG00000 ┆ … ┆ 291       ┆ 0.089552  ┆ 0.685201  ┆ 0.493814 │
# │ 131482    ┆           ┆ y_water_m ┆ 131482    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ass_int   ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC1     ┆ apolipopr ┆ ENSG00000 ┆ … ┆ 275       ┆ 0.090226  ┆ 0.796608  ┆ 0.426395 │
# │ 131482    ┆           ┆ otein_b_i ┆ 131482    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ nt        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC      ┆ creatinin ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 131482    ┆           ┆ e_int     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC      ┆ arm_predi ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 131482    ┆           ┆ cted_mass ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _right_in ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ t         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC1     ┆ arm_fatfr ┆ ENSG00000 ┆ … ┆ 291       ┆ 0.089552  ┆ 0.500214  ┆ 0.617338 │
# │ 131482    ┆           ┆ ee_mass_r ┆ 131482    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ G6PC1     ┆ arm_predi ┆ ENSG00000 ┆ … ┆ 291       ┆ 0.089552  ┆ -0.168416 ┆ 0.866384 │
# │ 131482    ┆           ┆ cted_mass ┆ 131482    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ _left_int ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC1     ┆ arm_fatfr ┆ ENSG00000 ┆ … ┆ 291       ┆ 0.089552  ┆ -0.077026 ┆ 0.93866  │
# │ 131482    ┆           ┆ ee_mass_l ┆ 131482    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ eft_int   ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC      ┆ creactive ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 131482    ┆           ┆ _protein_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ int       ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC      ┆ arm_fatfr ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 131482    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ G6PC      ┆ cholester ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 131482    ┆           ┆ ol_int    ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Analyse results

# %%
plof = (
    # pl.read_parquet('/home/dnanexus/data_dir/association_files/rvat_EUR_500k_regenie.parquet')
    pl.read_parquet('/home/dnanexus/data_dir/association_files/rvat_EUR_500k_regenie_am_plof.parquet')
    .with_columns(
        # phenotype = (pl.col('trait') + '_int'),
        # region = pl.col('gene_id'),
        phenotype = (pl.col('phenotype') + '_int'),
        rvat_pval = (10** -pl.col("neg_log10p")),
    )
    .with_columns(
        p_adj_bonf = pl.min_horizontal(pl.col('rvat_pval')*17_000, 1),
    )
    .filter(
        (pl.col('trait_type') == 'quantitative')
    )
)

# lofcorr_df = pl.read_parquet("/home/dnanexus/data_dir/association_files/loftee_correlation_quantitative_EUR_genebass1e6coding_maf1e3.parquet")
lofcorr_df = pl.read_parquet("/home/dnanexus/data_dir/association_files/am_loftee_correlation_quantitative_EUR_genebass1e6coding_maf1e3.parquet")

plof = plof[['region', 'gene_name', 'phenotype', 'beta', 'rvat_pval', 'p_adj_bonf']].join(lofcorr_df, on=['region', 'gene_name', 'phenotype'], how='inner')

plof
# Out:
# shape: (239_674, 20)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ region    ┆ gene_name ┆ phenotype ┆ beta      ┆ … ┆ plof_prop ┆ am_loftee ┆ t_stat    ┆ p_value  │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ _prop     ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ f64       ┆   ┆ f64       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ list[f64] ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ AURKAIP1  ┆ arm_fatfr ┆ -0.027796 ┆ … ┆ 0.080189  ┆ [0.863208 ┆ -1.052026 ┆ 0.293997 │
# │ 175756    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆ 0.311321, ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.00471…  ┆           ┆          │
# │ ENSG00000 ┆ GNB1      ┆ arm_fatfr ┆ 0.022958  ┆ … ┆ 0.005376  ┆ [0.629032 ┆ 0.402152  ┆ 0.688039 │
# │ 078369    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆ 0.048387, ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.00537…  ┆           ┆          │
# │ ENSG00000 ┆ SKI       ┆ arm_fatfr ┆ 0.0302175 ┆ … ┆ 0.01625   ┆ [0.7075,  ┆ 0.291118  ┆ 0.771036 │
# │ 157933    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆ 0.3425, … ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆ 0.00125]  ┆           ┆          │
# │ ENSG00000 ┆ MORN1     ┆ arm_fatfr ┆ 0.0778961 ┆ … ┆ 0.061508  ┆ [0.799603 ┆ 0.019063  ┆ 0.984798 │
# │ 116151    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆ 0.672619, ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.00198…  ┆           ┆          │
# │ ENSG00000 ┆ PANK4     ┆ arm_fatfr ┆ 0.0748588 ┆ … ┆ 0.043646  ┆ [0.543004 ┆ 1.716982  ┆ 0.086381 │
# │ 157881    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆ 0.392811, ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.00128…  ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ FBXW5     ┆ heel_bone ┆ 0.0780168 ┆ … ┆ 0.088525  ┆ [0.77541, ┆ 0.410462  ┆ 0.681612 │
# │ 159069    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆ 0.657377, ┆           ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆ 0.001639… ┆           ┆          │
# │ ENSG00000 ┆ ABCA2     ┆ heel_bone ┆ -0.040944 ┆ … ┆ 0.020513  ┆ [0.305983 ┆ -1.015644 ┆ 0.310009 │
# │ 107331    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆ 0.005128, ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.00085…  ┆           ┆          │
# │ ENSG00000 ┆ SLC34A3   ┆ heel_bone ┆ -0.026521 ┆ … ┆ 0.067757  ┆ [0.955607 ┆ -0.270124 ┆ 0.787195 │
# │ 198569    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆ 0.78972,  ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.002336… ┆           ┆          │
# │ ENSG00000 ┆ EHMT1     ┆ heel_bone ┆ 0.0378512 ┆ … ┆ 0.012216  ┆ [0.581152 ┆ 0.086825  ┆ 0.930841 │
# │ 181090    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆ 0.172775, ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.00174…  ┆           ┆          │
# │ ENSG00000 ┆ CACNA1B   ┆ heel_bone ┆ -0.018646 ┆ … ┆ 0.026897  ┆ [0.399616 ┆ 0.229651  ┆ 0.818408 │
# │ 148408    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆ ,         ┆           ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆ 0.264169, ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆ …         ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 0.00096…  ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
no_top_gt = (
    # pl.read_parquet("/home/dnanexus/data_dir/association_files/rvat_loftee_assocs_wo_top_plof_EUR_500k.parquet")
    pl.read_parquet("/home/dnanexus/data_dir/association_files/rvat_am_assocs_wo_top_plof_EUR_500k.parquet")
    .rename({
        # 'p_value': 'pval_wo_top_plof',
        # 'beta': 'beta_wo_top_plof',
        'p_value': 'pval_wo_top_plof',
        'beta': 'beta_wo_top_plof',
    })
    .select(
        # ['phenotype', 'gene_name', 'region', 'pval_wo_top_plof', 'beta_wo_top_plof', 'dropped_plof_count', 'n_variants']
        ['phenotype', 'gene_name', 'region', 'pval_wo_top_plof', 'beta_wo_top_plof', 'dropped_var_count',  'dropped_var', 'n_variants']
    )
)

no_top_gt
# Out:
# shape: (1_732, 8)
# ┌────────────┬───────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ phenotype  ┆ gene_name ┆ region     ┆ pval_wo_to ┆ beta_wo_t ┆ dropped_v ┆ dropped_v ┆ n_variant │
# │ ---        ┆ ---       ┆ ---        ┆ p_plof     ┆ op_plof   ┆ ar_count  ┆ ar        ┆ s         │
# │ str        ┆ str       ┆ str        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆           ┆            ┆ f64        ┆ f64       ┆ i64       ┆ str       ┆ i64       │
# ╞════════════╪═══════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ glycated_h ┆ PLD1      ┆ ENSG000000 ┆ 1.9242e-11 ┆ 0.13034   ┆ 537       ┆ chr3:1716 ┆ 752       │
# │ aemoglobin ┆           ┆ 75651      ┆            ┆           ┆           ┆ 86693:G:A ┆           │
# │ _hba1c_int ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ eosinophil ┆ PLD1      ┆ ENSG000000 ┆ 2.1670e-7  ┆ -0.106522 ┆ 556       ┆ chr3:1716 ┆ 759       │
# │ l_percenta ┆           ┆ 75651      ┆            ┆           ┆           ┆ 86693:G:A ┆           │
# │ ge_int     ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ red_blood_ ┆ PLD1      ┆ ENSG000000 ┆ 6.6890e-54 ┆ 0.31171   ┆ 556       ┆ chr3:1716 ┆ 759       │
# │ cell_eryth ┆           ┆ 75651      ┆            ┆           ┆           ┆ 86693:G:A ┆           │
# │ rocyte_dis ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ …          ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ reticulocy ┆ PLD1      ┆ ENSG000000 ┆ 0.000001   ┆ -0.100261 ┆ 545       ┆ chr3:1716 ┆ 756       │
# │ te_percent ┆           ┆ 75651      ┆            ┆           ┆           ┆ 86693:G:A ┆           │
# │ age_int    ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ eosinophil ┆ PLD1      ┆ ENSG000000 ┆ 3.5126e-7  ┆ -0.10332  ┆ 556       ┆ chr3:1716 ┆ 759       │
# │ l_count_in ┆           ┆ 75651      ┆            ┆           ┆           ┆ 86693:G:A ┆           │
# │ t          ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         │
# │ red_blood_ ┆ GAS6      ┆ ENSG000001 ┆ 0.000014   ┆ 0.148465  ┆ 524       ┆ chr13:113 ┆ 641       │
# │ cell_eryth ┆           ┆ 83087      ┆            ┆           ┆           ┆ 835614:G: ┆           │
# │ rocyte_cou ┆           ┆            ┆            ┆           ┆           ┆ A         ┆           │
# │ …          ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ glycated_h ┆ GAS6      ┆ ENSG000001 ┆ 1.2943e-8  ┆ 0.218822  ┆ 512       ┆ chr13:113 ┆ 632       │
# │ aemoglobin ┆           ┆ 83087      ┆            ┆           ┆           ┆ 835614:G: ┆           │
# │ _hba1c_int ┆           ┆            ┆            ┆           ┆           ┆ A         ┆           │
# │ red_blood_ ┆ GAS6      ┆ ENSG000001 ┆ 3.7815e-8  ┆ 0.219951  ┆ 524       ┆ chr13:113 ┆ 641       │
# │ cell_eryth ┆           ┆ 83087      ┆            ┆           ┆           ┆ 835614:G: ┆           │
# │ rocyte_dis ┆           ┆            ┆            ┆           ┆           ┆ A         ┆           │
# │ …          ┆           ┆            ┆            ┆           ┆           ┆           ┆           │
# │ triglyceri ┆ GAS6      ┆ ENSG000001 ┆ 3.2229e-9  ┆ 0.234782  ┆ 516       ┆ chr13:113 ┆ 638       │
# │ des_int    ┆           ┆ 83087      ┆            ┆           ┆           ┆ 835614:G: ┆           │
# │            ┆           ┆            ┆            ┆           ┆           ┆ A         ┆           │
# │ apolipopro ┆ GAS6      ┆ ENSG000001 ┆ 9.3241e-9  ┆ 0.232304  ┆ 515       ┆ chr13:113 ┆ 639       │
# │ tein_b_int ┆           ┆ 83087      ┆            ┆           ┆           ┆ 835614:G: ┆           │
# │            ┆           ┆            ┆            ┆           ┆           ┆ A         ┆           │
# └────────────┴───────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %%
# gt_all = gene_trait_df.join(no_top_gt, on=['phenotype', 'gene_name', 'region'], how='left')
gt_all = plof.filter(pl.col('p_adj_bonf') < 0.05).join(no_top_gt, on=['phenotype', 'gene_name', 'region'], how='left')
gt_all
# Out:
# shape: (1_732, 25)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ region    ┆ gene_name ┆ phenotype ┆ beta      ┆ … ┆ beta_wo_t ┆ dropped_v ┆ dropped_v ┆ n_varian │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ op_plof   ┆ ar_count  ┆ ar        ┆ ts_right │
# │ str       ┆ str       ┆ str       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ i64       ┆ str       ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ PAPPA2    ┆ arm_fatfr ┆ -0.268409 ┆ … ┆ -0.154199 ┆ 374       ┆ chr1:1766 ┆ 1280     │
# │ 116183    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆           ┆ 90374:C:T ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ DTL       ┆ arm_fatfr ┆ -0.207932 ┆ … ┆ -0.074513 ┆ 232       ┆ chr1:2120 ┆ 486      │
# │ 143476    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆           ┆ 72111:C:G ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ HTRA1     ┆ arm_fatfr ┆ -0.118306 ┆ … ┆ -0.084934 ┆ 333       ┆ chr10:122 ┆ 475      │
# │ 166033    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆           ┆ 489528:C: ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆ T         ┆          │
# │ ENSG00000 ┆ CNPY2     ┆ arm_fatfr ┆ -0.197164 ┆ … ┆ -0.205773 ┆ 136       ┆ chr12:563 ┆ 141      │
# │ 257727    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆           ┆ 14922:C:T ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ HMGA2     ┆ arm_fatfr ┆ -0.716889 ┆ … ┆ -0.655059 ┆ 60        ┆ chr12:659 ┆ 63       │
# │ 149948    ┆           ┆ ee_mass_r ┆           ┆   ┆           ┆           ┆ 51407:C:G ┆          │
# │           ┆           ┆ ight_int  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ CA1       ┆ reticuloc ┆ 0.443087  ┆ … ┆ 0.453198  ┆ 272       ┆ chr8:8532 ┆ 199      │
# │ 133742    ┆           ┆ yte_count ┆           ┆   ┆           ┆           ┆ 9784:A:G  ┆          │
# │           ┆           ┆ _int      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ VPS13A    ┆ reticuloc ┆ 0.196779  ┆ … ┆ 0.09507   ┆ 465       ┆ chr9:7731 ┆ 2047     │
# │ 197969    ┆           ┆ yte_count ┆           ┆   ┆           ┆           ┆ 5309:G:A  ┆          │
# │           ┆           ┆ _int      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ LRP5      ┆ heel_bone ┆ -0.491529 ┆ … ┆ -0.266359 ┆ 217       ┆ chr11:684 ┆ 940      │
# │ 162337    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆           ┆ 10004:A:T ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ WNT1      ┆ heel_bone ┆ -0.596645 ┆ … ┆ -0.543709 ┆ 280       ┆ chr12:489 ┆ 162      │
# │ 125084    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆           ┆ 81281:G:C ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ENSG00000 ┆ MEPE      ┆ heel_bone ┆ -0.45243  ┆ … ┆ -0.2654   ┆ 250       ┆ chr4:8784 ┆ 222      │
# │ 152595    ┆           ┆ _mineral_ ┆           ┆   ┆           ┆           ┆ 5484:A:C  ┆          │
# │           ┆           ┆ density_b ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ md_…      ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
wdir_df = (
    gt_all
    .filter(
        (pl.col('beta')*pl.col('beta_wo_top_plof') < 0)
        # (pl.col('rvat_pval') < 0.05) &
        # (pl.col('pval_wo_top_plof') > 0.05/17_500)
    )
    # .with_columns(
    #     beta_delta = (pl.col('beta') - pl.col('beta_wo_top_plof')).abs(),
    # )
    
    # .select(
    #     # ['phenotype', 'gene_name', 'region', 'beta', 'beta_wo_top_plof', 'n_individuals_plof', 'top_plof_var', 'pval_wo_top_plof', 'rvat_pval', 'dropped_plof_count', 'beta_delta' ]
    #     ['phenotype', 'gene_name', 'region', 'beta', 'beta_wo_top_plof', 'n_individuals_plof', 'n_individuals_var', 'top_var', 'top_var_count', 'pval_wo_top_plof', 'rvat_pval', 'beta_delta' ]
    # )
    # .sort('beta_delta', descending=True)
)

wdir_df
# Out:
# shape: (2, 25)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ region    ┆ gene_name ┆ phenotype ┆ beta     ┆ … ┆ beta_wo_t ┆ dropped_v ┆ dropped_v ┆ n_variant │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆   ┆ op_plof   ┆ ar_count  ┆ ar        ┆ s_right   │
# │ str       ┆ str       ┆ str       ┆ f64      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆           ┆          ┆   ┆ f64       ┆ i64       ┆ str       ┆ i64       │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ ENSG00000 ┆ MRPL18    ┆ lipoprote ┆ 0.72496  ┆ … ┆ -0.013003 ┆ 561       ┆ chr6:1597 ┆ 284       │
# │ 112110    ┆           ┆ in_a_int  ┆          ┆   ┆           ┆           ┆ 97411:G:T ┆           │
# │ ENSG00000 ┆ FLG       ┆ vitamin_d ┆ 0.169682 ┆ … ┆ -0.012629 ┆ 720       ┆ chr1:1523 ┆ 5552      │
# │ 143631    ┆           ┆ _int      ┆          ┆   ┆           ┆           ┆ 07927:T:G ┆           │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
plt_df = pd.DataFrame({
    'categories': [
        'bonf. significant\n(all individuals)', 
        'nom. significant\n(w/o top plof)', 
        'bonf. significant\n(w/o top plof)', 
    ],
    'numbers': [
        gt_all.shape[0], 
        gt_all.filter(pl.col('pval_wo_top_plof')<0.05).shape[0],
        gt_all.filter(pl.col('pval_wo_top_plof')<0.05/17_500).shape[0],
    ]
})

category_order = plt_df['categories'].to_list()
plt_df['categories'] = pd.Categorical(
    plt_df['categories'].to_list(),
    categories=category_order,
    ordered=True
)


# --- 4. Create the Plot ---
(
    ggplot(plt_df, aes(x='categories', y='numbers'))
    + geom_col(fill='steelblue')
    + geom_text(
        aes(label='numbers'),
        va='bottom',
        nudge_y=0.001 * plt_df['numbers'].max(),
        size=10
    )
    + labs(
        x='',
        y='gene-trait associations',
    )
    + theme_minimal()
    + theme(
        figure_size=(3, 5),
        axis_text_x=element_text(rotation=45, hjust=1),
    )
)

# %%
dir_df = pd.DataFrame({
    'categories': [ 
        'not nom. significant\n(w/o top plof)',
        'wrong direction\n(w/o top plof)',
    ],
    'numbers': [
        gt_all.filter(pl.col('pval_wo_top_plof')>0.05).shape[0],
        gt_all.filter(pl.col('beta')*pl.col('beta_wo_top_plof') < 0).shape[0],
    ]
})

category_order = dir_df['categories'].to_list()
dir_df['categories'] = pd.Categorical(
    dir_df['categories'].to_list(),
    categories=category_order,
    ordered=True
)


# --- 4. Create the Plot ---
(
    ggplot(dir_df, aes(x='categories', y='numbers'))
    + geom_col(fill='steelblue')
    + geom_text(
        aes(label='numbers'),
        va='bottom',
        nudge_y=0.001 * dir_df['numbers'].max(),
        size=10
    )
    + labs(
        x='',
        y='gene-trait associations',
    )
    + theme_minimal()
    + theme(
        figure_size=(2, 5),
        axis_text_x=element_text(rotation=45, hjust=1),
    )
)
